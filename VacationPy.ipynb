# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
#!pip install ipywidgets

from dotenv import load_dotenv
import os
import json
from pprint import pprint
load_dotenv()
API_KEY=os.getenv('google_api_key')
#!pip install gmaps
#!jupyter nbextension enable --py widgetsnbextension --sys-prefix
#!jupyter nbextension enable --py widgetsnbextension
#!jupyter nbextension enable --py --sys-prefix gmaps
#from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
vacationdf=pd.read_csv('weatherdf.csv')
vacationdf
# Out:
#      Unnamed: 0                                       city  lattitude  \
# 0             0                            Arraial do Cabo   -22.9661
# 1             1                                      Pevek    69.7008
# 2             2                                       Poum   -20.2333
# 3             3                                   Tasiilaq    65.6145
# 4             4                       Vila Franca do Campo    37.7167
# 5             5                               Punta Arenas   -53.1500
# 6             6                                    Qaanaaq    77.4840
# 7             7                                    Mataura   -46.1927
# 8             8                                Grand Gaube   -20.0064
# 9             9                                  Mahébourg   -20.4081
# 10           10                                     Faanui   -16.4833
# 11           11                                Tuktoyaktuk    69.4541
# 12           12                                     Ferrol    43.4832
# 13           13                                Yellowknife    62.4560
# 14           14                                      Bluff   -46.6000
# 15           15                                      Cervo    43.6702
# 16           16                                  Penugonda    16.6667
# 17           17                            Severo-Kuril'sk    50.6789
# 18           18                                    Sørland    67.6670
# 19           19                                     Llanes    43.4198
# 20           20                                 Hambantota     6.1241
# 21           21                                  Cape Town   -33.9258
# 22           22                                       Hilo    19.7297
# 23           23                                     Gatton   -27.5500
# 24           24                                     Barrow    71.2906
# 25           25                                   Qaqortoq    60.7167
# 26           26                                     Avarua   -21.2078
# 27           27                                    Fortuna    40.5982
# 28           28                                  Fairbanks    64.8378
# 29           29                                      Sitka    57.0531
# ..          ...                                        ...        ...
# 546         546                                Black River    18.0264
# 547         547                                     Monywa    22.1167
# 548         548                                  Hay River    60.8156
# 549         549                                     Aranos   -24.1333
# 550         550  Arrondissement de Saint-Jean-de-Maurienne    45.1667
# 551         551                                  Plainview    40.7765
# 552         552                                 Tuscaloosa    33.2098
# 553         553                                 Talcahuano   -36.7167
# 554         554                                  Innisfail   -17.5333
# 555         555                                     Kobryn    52.2138
# 556         556                                     Konëvo    62.1215
# 557         557                                     Sokoni    -6.4333
# 558         558                                 Vila Velha   -20.3297
# 559         559                                     Madang    -5.2246
# 560         560                                      Minbu    20.1833
# 561         561                                  Jiaojiang    28.6803
# 562         562                                     Camopi     3.1655
# 563         563                                 Tarko-Sale    64.9225
# 564         564                                  Gladstone   -23.8500
# 565         565                                       Diré    12.2833
# 566         566                                    Isangel   -19.5500
# 567         567                                    Chekhov    55.1431
# 568         568                                   Ust'-Uda    54.1742
# 569         569                                      Hobyo     5.3505
# 570         570                              Berdigestyakh    62.0989
# 571         571                                     Shīeli    44.1667
# 572         572                                New Glasgow    45.5834
# 573         573                                 Phan Thiet    10.9333
# 574         574                                 Nur-Sultan    51.1801
# 575         575                             Preobrazheniye    42.9019
#
# 564   151.2500     60.73        82           1        1.14      AU  1630064459
# 565   -10.9667     83.32        77          95        2.17      ML  1630064460
# 566   169.2667     70.56        74           3        6.80      VU  1630064460
# 567    37.4711     73.63        40          84       11.50      RU  1630064460
# 568   103.0304     62.24        53          10        2.17      RU  1630064460
# 569    48.5268     82.06        66           9       30.36      SO  1630064461
# 570   126.6992     41.41        86         100        9.22      RU  1630064461
# 571    66.7500     97.79        11          27        9.78      KZ  1630064461
# 572   -62.6486     72.10        83           3        8.55      CA  1630064462
# 573   108.1000     77.65        87          98        3.40      VN  1630064462
# 574    71.4460     85.95        23           0       11.18      KZ  1630064462
# 575   133.9064     69.04        78          99        7.20      RU  1630064463
#
# [576 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure GMAPS
gmaps.configure(API_KEY)

# %%
humidity=vacationdf['humidity'].astype(float)
max_humidity=humidity.max()
city=vacationdf[['lattitude','longitude']]
fig=gmaps.figure(center = [31.9686, -99.9018], zoom_level = 3)
heat_layer=gmaps.heatmap_layer(city,weights=humidity,max_intensity=max_humidity,dissipating=False,point_radius=2)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
best=vacationdf.loc[(vacationdf['max_temp']<75)&(vacationdf['max_temp']>70)&(vacationdf['cloudiness']<10)]
best
# Out:
#      Unnamed: 0            city  lattitude  longitude  max_temp  humidity  \
# 56           56  Guerrero Negro    27.9769  -114.0611     72.84        80
# 136         136           Ukiah    39.1502  -123.2078     72.03        65
# 227         227       Matamoros    25.5333  -103.2500     70.11        65
# 237         237          Shunyi    40.1250   116.6453     73.35        60
# 281         281          Panjāb    34.3880    67.0233     73.42        11
# 385         385         Russell    32.3502   -85.1999     74.91        90
# 425         425         Camargo    27.6667  -105.1667     70.66        62
# 477         477         Jiménez    28.3333  -105.4000     70.61        61
# 494         494    Port Hedland   -20.3167   118.5667     73.45        78
# 516         516          Laguna    38.4210  -121.4238     73.76        67
# 528         528        Magnolia    33.2671   -93.2393     71.29        96
# 549         549          Aranos   -24.1333    19.1167     73.36        11
# 552         552      Tuscaloosa    33.2098   -87.5692     74.98        95
# 566         566         Isangel   -19.5500   169.2667     70.56        74
# 572         572     New Glasgow    45.5834   -62.6486     72.10        83
#
#      cloudiness  wind_speed country        date
# 56            0        4.27      MX  1630064287
# 136           1        0.00      US  1630064086
# 227           5        5.30      MX  1630064344
# 237           0        4.47      CN  1630064348
# 281           5        9.06      AF  1630064362
# 385           1        3.44      US  1630064398
# 425           6        4.14      MX  1630064414
# 477           9        2.91      MX  1630064431
# 494           0        8.05      AU  1630064437
# 516           1        3.44      US  1630064444
# 528           2        3.67      US  1630064184
# 549           0       15.30     NaN  1630064455
# 552           1        3.44      US  1630064456
# 566           3        6.80      VU  1630064460
# 572           3        8.55      CA  1630064462

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#Store into variable named hotel_df.
#Add a "Hotel Name" column to the DataFrame.
#best1=best
best['hotel']='nan'

best1=best
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
hlist=len(set(best1['Unnamed: 0']))
hlist
# Out:
# 15

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    'type':"lodging",
    "keyword":"hotel",
    "radius": 20000,
    "key": API_KEY,
}

# %%
for  index,row in best1.iterrows():
    lat=row['lattitude']
    lng=row['longitude']
    city=row['city']
    params['location']=f'{lat},{lng}'
    print (f'retriving {city}')
    
    response=requests.get(base_url,params=params).json()
    results=response['results']
    
    try:
        best1.loc[index,'hotel']=results[0]['name']
    except (KeyError,IndexError):
        print("missing")
# Out:
# retriving Guerrero Negro
# missing
# retriving Ukiah
# missing
# retriving Matamoros
# missing
# retriving Shunyi
# missing
# retriving Panjāb
# missing
# retriving Russell
# missing
# retriving Camargo
# missing
# retriving Jiménez
# missing
# retriving Port Hedland
# missing
# retriving Laguna
# missing
# retriving Magnolia
# missing
# retriving Aranos
# missing
# retriving Tuscaloosa
# missing
# retriving Isangel
# missing
# retriving New Glasgow
# missing

# %%
best1
# Out:
#      Unnamed: 0            city  lattitude  longitude  max_temp  humidity  \
# 56           56  Guerrero Negro    27.9769  -114.0611     72.84        80
# 136         136           Ukiah    39.1502  -123.2078     72.03        65
# 227         227       Matamoros    25.5333  -103.2500     70.11        65
# 237         237          Shunyi    40.1250   116.6453     73.35        60
# 281         281          Panjāb    34.3880    67.0233     73.42        11
# 385         385         Russell    32.3502   -85.1999     74.91        90
# 425         425         Camargo    27.6667  -105.1667     70.66        62
# 477         477         Jiménez    28.3333  -105.4000     70.61        61
# 494         494    Port Hedland   -20.3167   118.5667     73.45        78
# 516         516          Laguna    38.4210  -121.4238     73.76        67
# 528         528        Magnolia    33.2671   -93.2393     71.29        96
# 549         549          Aranos   -24.1333    19.1167     73.36        11
# 552         552      Tuscaloosa    33.2098   -87.5692     74.98        95
# 566         566         Isangel   -19.5500   169.2667     70.56        74
# 572         572     New Glasgow    45.5834   -62.6486     72.10        83
#
#      cloudiness  wind_speed country        date hotel
# 56            0        4.27      MX  1630064287   nan
# 136           1        0.00      US  1630064086   nan
# 227           5        5.30      MX  1630064344   nan
# 237           0        4.47      CN  1630064348   nan
# 281           5        9.06      AF  1630064362   nan
# 385           1        3.44      US  1630064398   nan
# 425           6        4.14      MX  1630064414   nan
# 477           9        2.91      MX  1630064431   nan
# 494           0        8.05      AU  1630064437   nan
# 516           1        3.44      US  1630064444   nan
# 528           2        3.67      US  1630064184   nan
# 549           0       15.30     NaN  1630064455   nan
# 552           1        3.44      US  1630064456   nan
# 566           3        6.80      VU  1630064460   nan
# 572           3        8.55      CA  1630064462   nan

# %%
# copy: Do not change any of the code in this cell


# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{hotel}</dd>
<dt>city</dt><dd>{city}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in best1.iterrows()]
locations = best1[["lattitude", "longitude"]]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>city</dt><dd>{city}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-6f409c33fae6> in <module>()
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# NameError: name 'hotel_df' is not defined

# %%
print(info_box_template)
print(hotel_info)
# Out:
# <dl>
# <dt>Name</dt><dd>{hotel}</dd>
# <dt>city</dt><dd>{city}</dd>
# <dt>Country</dt><dd>{country}</dd>
# </dl>
#
# ['\n<dl>\n<dt>Name</dt><dd>The Halfway Inn</dd>\n<dt>city</dt><dd>Guerrero Negro</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>The Lodge at Blue Lakes</dd>\n<dt>city</dt><dd>Ukiah</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>ibis Torreón</dd>\n<dt>city</dt><dd>Matamoros</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>The Great Wall Sheraton Hotel Beijing</dd>\n<dt>city</dt><dd>Shunyi</dd>\n<dt>Country</dt><dd>CN</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>nan</dd>\n<dt>city</dt><dd>Panjāb</dd>\n<dt>Country</dt><dd>AF</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hampton Inn & Suites Phenix City- Columbus Area</dd>\n<dt>city</dt><dd>Russell</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel Santa Fe</dd>\n<dt>city</dt><dd>Camargo</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>CASA GRANDE DELICIAS</dd>\n<dt>city</dt><dd>Jiménez</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hospitality Port Hedland</dd>\n<dt>city</dt><dd>Port Hedland</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hampton Inn & Suites Sacramento-Elk Grove Laguna I-5</dd>\n<dt>city</dt><dd>Laguna</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Quality Inn Magnolia</dd>\n<dt>city</dt><dd>Magnolia</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Aranos Hotel</dd>\n<dt>city</dt><dd>Aranos</dd>\n<dt>Country</dt><dd>nan</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel Capstone</dd>\n<dt>city</dt><dd>Tuscaloosa</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>White Grass Ocean Resort & Spa</dd>\n<dt>city</dt><dd>Isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Holiday Inn Express Stellarton-New Glasgow, an IHG Hotel</dd>\n<dt>city</dt><dd>New Glasgow</dd>\n<dt>Country</dt><dd>CA</dd>\n</dl>\n']

# %%
# Add marker layer ontop of heat map
markers=gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(markers)
fig

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
